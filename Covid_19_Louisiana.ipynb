# %% [markdown]
# # Covid-19 Cases in Louisiana by day

# %% [markdown]
# Import statements

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %% [markdown]
# Create general dataframe

# %%
stateurl = 'https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv'
countyurl = 'https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv'
states = pd.read_csv(stateurl)
counties = pd.read_csv(countyurl)
states.reset_index(inplace=True)
counties.reset_index(inplace=True)

# %% [markdown]
# Create Louisiana dataframes

# %%
LA = states[states['state']=='Louisiana']
NOLA = counties[(counties['county']=='Orleans') & (counties['state']=='Louisiana')]
Jefferson = counties[(counties['county']=='Jefferson') & (counties['state']=='Louisiana')]
EBR = counties[(counties['county']=='East Baton Rouge') & (counties['state']=='Louisiana')]

# %% [markdown]
# Number of deaths in Louisiana

# %%
fig1 = plt.figure()
axes = fig1.add_axes([0,0,5,3])
axes.scatter(LA['date'], LA['deaths'], LA['cases'])
axes.set_xlabel('Date')
axes.set_ylabel('Number of Cases')
axes.set_title('Louisiana Covid-19 Deaths')
# Out:
# Text(0.5, 1.0, 'Louisiana Covid-19 Deaths')

# %% [markdown]
# Number of deaths in New Orleans

# %%
fig2 = plt.figure()
axes = fig2.add_axes([0,0,5,2])
axes.scatter(NOLA['date'], NOLA['deaths'], NOLA['cases'])
axes.set_xlabel('Date')
axes.set_ylabel('Number of Deaths')
axes.set_title('New Orleans Covid-19 Deaths')
# Out:
# Text(0.5, 1.0, 'New Orleans Covid-19 Deaths')
